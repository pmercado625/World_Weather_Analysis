# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size = 2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size = 2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9a6602e1e86bb8457c6884a9b4f2c55e

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 745

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_desc = city_weather["weather"][0]['description']
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_desc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | preobrazheniye
# Processing Record 2 of Set 1 | huarmey
# Processing Record 3 of Set 1 | renfrew
# Processing Record 4 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 5 of Set 1 | tuktoyaktuk
# Processing Record 6 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 7 of Set 1 | atuona
# Processing Record 8 of Set 1 | ponta do sol
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | bluff
# Processing Record 11 of Set 1 | cape town
# Processing Record 12 of Set 1 | nikolskoye
# Processing Record 13 of Set 1 | kapaa
# Processing Record 14 of Set 1 | bermejo
# Processing Record 15 of Set 1 | sogdiondon
# City not found. Skipping...
# Processing Record 16 of Set 1 | talawdi
# City not found. Skipping...
# Processing Record 17 of Set 1 | zaraysk
# Processing Record 18 of Set 1 | yellowknife
# Processing Record 19 of Set 1 | ushuaia
# Processing Record 20 of Set 1 | uryupinsk
# Processing Record 21 of Set 1 | bargal
# City not found. Skipping...
# Processing Record 22 of Set 1 | gambela
# Processing Record 23 of Set 1 | omboue
# Processing Record 24 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 25 of Set 1 | shingu
# Processing Record 26 of Set 1 | clinton
# Processing Record 27 of Set 1 | busselton
# Processing Record 28 of Set 1 | punta arenas
# Processing Record 29 of Set 1 | asau
# Processing Record 30 of Set 1 | pacifica
# Processing Record 31 of Set 1 | xinyang
# Processing Record 32 of Set 1 | airai
# Processing Record 33 of Set 1 | arraial do cabo
# Processing Record 34 of Set 1 | hithadhoo
# Processing Record 35 of Set 1 | hilo
# Processing Record 36 of Set 1 | goteborg
# City not found. Skipping...
# Processing Record 37 of Set 1 | leningradskiy
# Processing Record 38 of Set 1 | kavieng
# Processing Record 39 of Set 1 | ushtobe
# Processing Record 40 of Set 1 | arbagar
# Processing Record 41 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 42 of Set 1 | saint anthony
# Processing Record 43 of Set 1 | matay
# Processing Record 44 of Set 1 | makakilo city
# Processing Record 45 of Set 1 | kahului
# Processing Record 46 of Set 1 | longyearbyen
# Processing Record 47 of Set 1 | barrow
# Processing Record 48 of Set 1 | juneau
# Processing Record 49 of Set 1 | ridgetown
# Processing Record 50 of Set 1 | feijo
# Processing Record 1 of Set 2 | cidreira
# Processing Record 2 of Set 2 | dikson
# Processing Record 3 of Set 2 | caravelas
# Processing Record 4 of Set 2 | mataura
# Processing Record 5 of Set 2 | novi becej
# Processing Record 6 of Set 2 | haines junction
# Processing Record 7 of Set 2 | sistranda
# Processing Record 8 of Set 2 | qaanaaq
# Processing Record 9 of Set 2 | grand gaube
# Processing Record 10 of Set 2 | odienne
# Processing Record 11 of Set 2 | maykain
# City not found. Skipping...
# Processing Record 12 of Set 2 | mar del plata
# Processing Record 13 of Set 2 | kazalinsk
# City not found. Skipping...
# Processing Record 14 of Set 2 | portland
# Processing Record 15 of Set 2 | avarua
# Processing Record 16 of Set 2 | west bay
# Processing Record 17 of Set 2 | margate
# Processing Record 18 of Set 2 | jamestown
# Processing Record 19 of Set 2 | port alfred
# Processing Record 20 of Set 2 | albany
# Processing Record 21 of Set 2 | fort nelson
# Processing Record 22 of Set 2 | tabiauea
# City not found. Skipping...
# Processing Record 23 of Set 2 | buala
# Processing Record 24 of Set 2 | atoka
# Processing Record 25 of Set 2 | anaconda
# Processing Record 26 of Set 2 | new norfolk
# Processing Record 27 of Set 2 | bredasdorp
# Processing Record 28 of Set 2 | bulri
# Processing Record 29 of Set 2 | porlamar
# Processing Record 30 of Set 2 | meyungs
# City not found. Skipping...
# Processing Record 31 of Set 2 | namibe
# Processing Record 32 of Set 2 | burgos
# Processing Record 33 of Set 2 | victoria
# Processing Record 34 of Set 2 | fortuna
# Processing Record 35 of Set 2 | sinnamary
# Processing Record 36 of Set 2 | kapit
# Processing Record 37 of Set 2 | hermanus
# Processing Record 38 of Set 2 | gogrial
# Processing Record 39 of Set 2 | saint-augustin
# Processing Record 40 of Set 2 | vaini
# Processing Record 41 of Set 2 | tasiilaq
# Processing Record 42 of Set 2 | kiama
# Processing Record 43 of Set 2 | santa maria del oro
# Processing Record 44 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 45 of Set 2 | alofi
# Processing Record 46 of Set 2 | cedar city
# Processing Record 47 of Set 2 | taoudenni
# Processing Record 48 of Set 2 | mitu
# Processing Record 49 of Set 2 | afsin
# Processing Record 50 of Set 2 | butaritari
# Processing Record 1 of Set 3 | luena
# Processing Record 2 of Set 3 | ketchikan
# Processing Record 3 of Set 3 | almaznyy
# Processing Record 4 of Set 3 | vila velha
# Processing Record 5 of Set 3 | klaksvik
# Processing Record 6 of Set 3 | tuatapere
# Processing Record 7 of Set 3 | thompson
# Processing Record 8 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 9 of Set 3 | mrirt
# City not found. Skipping...
# Processing Record 10 of Set 3 | mwene-ditu
# Processing Record 11 of Set 3 | cherskiy
# Processing Record 12 of Set 3 | khatanga
# Processing Record 13 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 14 of Set 3 | hayvoron
# Processing Record 15 of Set 3 | yagodnoye
# Processing Record 16 of Set 3 | san patricio
# Processing Record 17 of Set 3 | sao caetano de odivelas
# Processing Record 18 of Set 3 | komsomolskiy
# Processing Record 19 of Set 3 | galiwinku
# City not found. Skipping...
# Processing Record 20 of Set 3 | salisbury
# Processing Record 21 of Set 3 | grindavik
# Processing Record 22 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 23 of Set 3 | pisco
# Processing Record 24 of Set 3 | geraldton
# Processing Record 25 of Set 3 | rawson
# Processing Record 26 of Set 3 | clyde river
# Processing Record 27 of Set 3 | sao filipe
# Processing Record 28 of Set 3 | bodden town
# Processing Record 29 of Set 3 | brownwood
# Processing Record 30 of Set 3 | meulaboh
# Processing Record 31 of Set 3 | beringovskiy
# Processing Record 32 of Set 3 | vila
# Processing Record 33 of Set 3 | conceicao do araguaia
# Processing Record 34 of Set 3 | doha
# Processing Record 35 of Set 3 | rocha
# Processing Record 36 of Set 3 | micheweni
# Processing Record 37 of Set 3 | maceio
# Processing Record 38 of Set 3 | chokurdakh
# Processing Record 39 of Set 3 | hobart
# Processing Record 40 of Set 3 | torbay
# Processing Record 41 of Set 3 | sitka
# Processing Record 42 of Set 3 | guerrero negro
# Processing Record 43 of Set 3 | lyuban
# Processing Record 44 of Set 3 | aklavik
# Processing Record 45 of Set 3 | talnakh
# Processing Record 46 of Set 3 | tazovskiy
# Processing Record 47 of Set 3 | castro
# Processing Record 48 of Set 3 | yar-sale
# Processing Record 49 of Set 3 | san felipe
# Processing Record 50 of Set 3 | nouadhibou
# Processing Record 1 of Set 4 | saint george
# Processing Record 2 of Set 4 | hargeysa
# Processing Record 3 of Set 4 | bonthe
# Processing Record 4 of Set 4 | bengkulu
# Processing Record 5 of Set 4 | mahebourg
# Processing Record 6 of Set 4 | te anau
# Processing Record 7 of Set 4 | port elizabeth
# Processing Record 8 of Set 4 | oranjemund
# Processing Record 9 of Set 4 | linxia
# Processing Record 10 of Set 4 | khorixas
# Processing Record 11 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 12 of Set 4 | ixtapa
# Processing Record 13 of Set 4 | itarema
# Processing Record 14 of Set 4 | karauzyak
# City not found. Skipping...
# Processing Record 15 of Set 4 | valparaiso
# Processing Record 16 of Set 4 | solwezi
# Processing Record 17 of Set 4 | mnogovershinnyy
# Processing Record 18 of Set 4 | severo-kurilsk
# Processing Record 19 of Set 4 | nuuk
# Processing Record 20 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 21 of Set 4 | necochea
# Processing Record 22 of Set 4 | karratha
# Processing Record 23 of Set 4 | durban
# Processing Record 24 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 25 of Set 4 | weyburn
# Processing Record 26 of Set 4 | tynaarlo
# Processing Record 27 of Set 4 | auki
# Processing Record 28 of Set 4 | calabozo
# Processing Record 29 of Set 4 | hambantota
# Processing Record 30 of Set 4 | choix
# Processing Record 31 of Set 4 | la fleche
# Processing Record 32 of Set 4 | kaitangata
# Processing Record 33 of Set 4 | cap malheureux
# Processing Record 34 of Set 4 | puerto ayora
# Processing Record 35 of Set 4 | pimampiro
# Processing Record 36 of Set 4 | jutai
# Processing Record 37 of Set 4 | turbat
# Processing Record 38 of Set 4 | bethel
# Processing Record 39 of Set 4 | chenzhou
# Processing Record 40 of Set 4 | san rafael del sur
# Processing Record 41 of Set 4 | la ronge
# Processing Record 42 of Set 4 | yuancheng
# Processing Record 43 of Set 4 | chuy
# Processing Record 44 of Set 4 | constitucion
# Processing Record 45 of Set 4 | carnarvon
# Processing Record 46 of Set 4 | vanimo
# Processing Record 47 of Set 4 | saskylakh
# Processing Record 48 of Set 4 | odweyne
# Processing Record 49 of Set 4 | ijaki
# City not found. Skipping...
# Processing Record 50 of Set 4 | tukrah
# Processing Record 1 of Set 5 | banjar
# Processing Record 2 of Set 5 | coihaique
# Processing Record 3 of Set 5 | rabak
# Processing Record 4 of Set 5 | serra
# Processing Record 5 of Set 5 | east london
# Processing Record 6 of Set 5 | kuji
# Processing Record 7 of Set 5 | vostok
# Processing Record 8 of Set 5 | shahr-e babak
# Processing Record 9 of Set 5 | ilulissat
# Processing Record 10 of Set 5 | skalistyy
# City not found. Skipping...
# Processing Record 11 of Set 5 | ribeira grande
# Processing Record 12 of Set 5 | palmer
# Processing Record 13 of Set 5 | iqaluit
# Processing Record 14 of Set 5 | sorvag
# City not found. Skipping...
# Processing Record 15 of Set 5 | gorlice
# Processing Record 16 of Set 5 | ilo
# Processing Record 17 of Set 5 | saint-philippe
# Processing Record 18 of Set 5 | brae
# Processing Record 19 of Set 5 | kasongo
# Processing Record 20 of Set 5 | sabla
# Processing Record 21 of Set 5 | nome
# Processing Record 22 of Set 5 | georgetown
# Processing Record 23 of Set 5 | mahon
# Processing Record 24 of Set 5 | mancio lima
# Processing Record 25 of Set 5 | mae sai
# Processing Record 26 of Set 5 | jega
# Processing Record 27 of Set 5 | bambous virieux
# Processing Record 28 of Set 5 | arawa
# Processing Record 29 of Set 5 | hamilton
# Processing Record 30 of Set 5 | aflu
# City not found. Skipping...
# Processing Record 31 of Set 5 | harbin
# Processing Record 32 of Set 5 | waddan
# Processing Record 33 of Set 5 | saint-pierre
# Processing Record 34 of Set 5 | bacuit
# City not found. Skipping...
# Processing Record 35 of Set 5 | bremerton
# Processing Record 36 of Set 5 | uetze
# Processing Record 37 of Set 5 | samarai
# Processing Record 38 of Set 5 | itoman
# Processing Record 39 of Set 5 | merauke
# Processing Record 40 of Set 5 | pocone
# Processing Record 41 of Set 5 | rincon
# Processing Record 42 of Set 5 | barra
# Processing Record 43 of Set 5 | kudahuvadhoo
# Processing Record 44 of Set 5 | saint-georges
# Processing Record 45 of Set 5 | vanavara
# Processing Record 46 of Set 5 | kikwit
# Processing Record 47 of Set 5 | lata
# Processing Record 48 of Set 5 | mount isa
# Processing Record 49 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 50 of Set 5 | mehamn
# Processing Record 1 of Set 6 | aloleng
# Processing Record 2 of Set 6 | alta floresta
# Processing Record 3 of Set 6 | kanata
# Processing Record 4 of Set 6 | saint-medard-en-jalles
# Processing Record 5 of Set 6 | carroll
# Processing Record 6 of Set 6 | pevek
# Processing Record 7 of Set 6 | lakatoro
# Processing Record 8 of Set 6 | hualmay
# Processing Record 9 of Set 6 | hirara
# Processing Record 10 of Set 6 | chapais
# Processing Record 11 of Set 6 | izumo
# Processing Record 12 of Set 6 | bridlington
# Processing Record 13 of Set 6 | katiola
# Processing Record 14 of Set 6 | moerai
# Processing Record 15 of Set 6 | qasigiannguit
# Processing Record 16 of Set 6 | entre rios
# Processing Record 17 of Set 6 | wampusirpi
# City not found. Skipping...
# Processing Record 18 of Set 6 | alice springs
# Processing Record 19 of Set 6 | paita
# Processing Record 20 of Set 6 | haimen
# Processing Record 21 of Set 6 | peterhead
# Processing Record 22 of Set 6 | zhigansk
# Processing Record 23 of Set 6 | arlit
# Processing Record 24 of Set 6 | pasni
# Processing Record 25 of Set 6 | ostrovnoy
# Processing Record 26 of Set 6 | nova vicosa
# Processing Record 27 of Set 6 | nemuro
# Processing Record 28 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 29 of Set 6 | kavaratti
# Processing Record 30 of Set 6 | batticaloa
# Processing Record 31 of Set 6 | urdzhar
# City not found. Skipping...
# Processing Record 32 of Set 6 | miraflores
# Processing Record 33 of Set 6 | utiroa
# City not found. Skipping...
# Processing Record 34 of Set 6 | high level
# Processing Record 35 of Set 6 | coahuayana
# Processing Record 36 of Set 6 | labutta
# City not found. Skipping...
# Processing Record 37 of Set 6 | calvinia
# Processing Record 38 of Set 6 | jamsa
# Processing Record 39 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 40 of Set 6 | pandan
# Processing Record 41 of Set 6 | the valley
# Processing Record 42 of Set 6 | kiruna
# Processing Record 43 of Set 6 | naze
# Processing Record 44 of Set 6 | puno
# Processing Record 45 of Set 6 | opelousas
# Processing Record 46 of Set 6 | matara
# Processing Record 47 of Set 6 | baghdad
# Processing Record 48 of Set 6 | yarkovo
# Processing Record 49 of Set 6 | puerto escondido
# Processing Record 50 of Set 6 | hasaki
# Processing Record 1 of Set 7 | yatou
# Processing Record 2 of Set 7 | faanui
# Processing Record 3 of Set 7 | lebu
# Processing Record 4 of Set 7 | egvekinot
# Processing Record 5 of Set 7 | udarnyy
# Processing Record 6 of Set 7 | touros
# Processing Record 7 of Set 7 | norman wells
# Processing Record 8 of Set 7 | prainha
# Processing Record 9 of Set 7 | agadir
# Processing Record 10 of Set 7 | port shepstone
# Processing Record 11 of Set 7 | boyolangu
# Processing Record 12 of Set 7 | roma
# Processing Record 13 of Set 7 | luderitz
# Processing Record 14 of Set 7 | polyarnyy
# Processing Record 15 of Set 7 | marathon
# Processing Record 16 of Set 7 | bauchi
# Processing Record 17 of Set 7 | cayenne
# Processing Record 18 of Set 7 | makat
# Processing Record 19 of Set 7 | moron
# Processing Record 20 of Set 7 | coquimbo
# Processing Record 21 of Set 7 | carinhanha
# Processing Record 22 of Set 7 | haibowan
# City not found. Skipping...
# Processing Record 23 of Set 7 | chimbarongo
# Processing Record 24 of Set 7 | canto do buriti
# Processing Record 25 of Set 7 | san cristobal
# Processing Record 26 of Set 7 | tutoia
# Processing Record 27 of Set 7 | moscow
# Processing Record 28 of Set 7 | wewak
# Processing Record 29 of Set 7 | tindivanam
# Processing Record 30 of Set 7 | darab
# Processing Record 31 of Set 7 | esperance
# Processing Record 32 of Set 7 | newport
# Processing Record 33 of Set 7 | port lincoln
# Processing Record 34 of Set 7 | yarmouth
# Processing Record 35 of Set 7 | leninskoye
# Processing Record 36 of Set 7 | shubarshi
# Processing Record 37 of Set 7 | conde
# Processing Record 38 of Set 7 | kilis
# Processing Record 39 of Set 7 | cerritos
# Processing Record 40 of Set 7 | vila franca do campo
# Processing Record 41 of Set 7 | maniitsoq
# Processing Record 42 of Set 7 | nanortalik
# Processing Record 43 of Set 7 | gayeri
# Processing Record 44 of Set 7 | grand forks
# Processing Record 45 of Set 7 | channarayapatna
# Processing Record 46 of Set 7 | ngukurr
# City not found. Skipping...
# Processing Record 47 of Set 7 | mlonggo
# Processing Record 48 of Set 7 | srandakan
# Processing Record 49 of Set 7 | nema
# Processing Record 50 of Set 7 | pitsunda
# Processing Record 1 of Set 8 | quang ngai
# Processing Record 2 of Set 8 | pathardi
# Processing Record 3 of Set 8 | walla walla
# Processing Record 4 of Set 8 | teya
# Processing Record 5 of Set 8 | at-bashi
# Processing Record 6 of Set 8 | xuddur
# Processing Record 7 of Set 8 | trincomalee
# Processing Record 8 of Set 8 | urusha
# Processing Record 9 of Set 8 | amazar
# Processing Record 10 of Set 8 | teguise
# Processing Record 11 of Set 8 | emerald
# Processing Record 12 of Set 8 | souillac
# Processing Record 13 of Set 8 | bayan
# Processing Record 14 of Set 8 | kintampo
# Processing Record 15 of Set 8 | tromso
# Processing Record 16 of Set 8 | palauig
# Processing Record 17 of Set 8 | taburi
# City not found. Skipping...
# Processing Record 18 of Set 8 | tura
# Processing Record 19 of Set 8 | boa vista
# Processing Record 20 of Set 8 | bonnyville
# Processing Record 21 of Set 8 | magadan
# Processing Record 22 of Set 8 | great yarmouth
# Processing Record 23 of Set 8 | laurel
# Processing Record 24 of Set 8 | ancud
# Processing Record 25 of Set 8 | kruisfontein
# Processing Record 26 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 27 of Set 8 | henzada
# City not found. Skipping...
# Processing Record 28 of Set 8 | upernavik
# Processing Record 29 of Set 8 | piryion
# City not found. Skipping...
# Processing Record 30 of Set 8 | kenai
# Processing Record 31 of Set 8 | severodvinsk
# Processing Record 32 of Set 8 | lompoc
# Processing Record 33 of Set 8 | mitchell
# Processing Record 34 of Set 8 | safwah
# City not found. Skipping...
# Processing Record 35 of Set 8 | liverpool
# Processing Record 36 of Set 8 | mahibadhoo
# Processing Record 37 of Set 8 | baruun-urt
# Processing Record 38 of Set 8 | scarborough
# Processing Record 39 of Set 8 | nguiu
# City not found. Skipping...
# Processing Record 40 of Set 8 | marawi
# Processing Record 41 of Set 8 | aksu
# Processing Record 42 of Set 8 | lorengau
# Processing Record 43 of Set 8 | matagami
# Processing Record 44 of Set 8 | jiaocheng
# Processing Record 45 of Set 8 | sataua
# City not found. Skipping...
# Processing Record 46 of Set 8 | hay river
# Processing Record 47 of Set 8 | ust-tsilma
# Processing Record 48 of Set 8 | moussoro
# Processing Record 49 of Set 8 | thinadhoo
# Processing Record 50 of Set 8 | ahuimanu
# Processing Record 1 of Set 9 | vao
# Processing Record 2 of Set 9 | rochester
# Processing Record 3 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 4 of Set 9 | lampang
# Processing Record 5 of Set 9 | saldanha
# Processing Record 6 of Set 9 | chicama
# Processing Record 7 of Set 9 | kanniyakumari
# Processing Record 8 of Set 9 | kargasok
# Processing Record 9 of Set 9 | datong
# Processing Record 10 of Set 9 | peebles
# Processing Record 11 of Set 9 | lagoa
# Processing Record 12 of Set 9 | shimoda
# Processing Record 13 of Set 9 | moranbah
# Processing Record 14 of Set 9 | port-cartier
# Processing Record 15 of Set 9 | lujan
# Processing Record 16 of Set 9 | cabanas
# Processing Record 17 of Set 9 | batemans bay
# Processing Record 18 of Set 9 | katherine
# Processing Record 19 of Set 9 | belvidere
# Processing Record 20 of Set 9 | urumqi
# Processing Record 21 of Set 9 | prince rupert
# Processing Record 22 of Set 9 | rio grande
# Processing Record 23 of Set 9 | mount pleasant
# Processing Record 24 of Set 9 | ouegoa
# Processing Record 25 of Set 9 | ayr
# Processing Record 26 of Set 9 | charters towers
# Processing Record 27 of Set 9 | bilibino
# Processing Record 28 of Set 9 | tilichiki
# Processing Record 29 of Set 9 | barreirinhas
# Processing Record 30 of Set 9 | shestakovo
# Processing Record 31 of Set 9 | dingle
# Processing Record 32 of Set 9 | istra
# Processing Record 33 of Set 9 | la palma
# Processing Record 34 of Set 9 | lavrentiya
# Processing Record 35 of Set 9 | tsirguliina
# Processing Record 36 of Set 9 | mujiayingzi
# Processing Record 37 of Set 9 | faya
# Processing Record 38 of Set 9 | tondano
# Processing Record 39 of Set 9 | srednekolymsk
# Processing Record 40 of Set 9 | macheng
# Processing Record 41 of Set 9 | mount gambier
# Processing Record 42 of Set 9 | sorland
# Processing Record 43 of Set 9 | sunbury
# Processing Record 44 of Set 9 | san quintin
# Processing Record 45 of Set 9 | bandarbeyla
# Processing Record 46 of Set 9 | ust-nera
# Processing Record 47 of Set 9 | sao gabriel da cachoeira
# Processing Record 48 of Set 9 | sur
# Processing Record 49 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 50 of Set 9 | tabou
# Processing Record 1 of Set 10 | katsuura
# Processing Record 2 of Set 10 | barawe
# City not found. Skipping...
# Processing Record 3 of Set 10 | yomitan
# City not found. Skipping...
# Processing Record 4 of Set 10 | santa cruz
# Processing Record 5 of Set 10 | riohacha
# Processing Record 6 of Set 10 | eldikan
# City not found. Skipping...
# Processing Record 7 of Set 10 | havoysund
# Processing Record 8 of Set 10 | carutapera
# Processing Record 9 of Set 10 | geneva
# Processing Record 10 of Set 10 | dongning
# Processing Record 11 of Set 10 | tiksi
# Processing Record 12 of Set 10 | divo
# Processing Record 13 of Set 10 | den helder
# Processing Record 14 of Set 10 | iquique
# Processing Record 15 of Set 10 | mmabatho
# Processing Record 16 of Set 10 | deputatskiy
# Processing Record 17 of Set 10 | georgievsk
# City not found. Skipping...
# Processing Record 18 of Set 10 | saint-joseph
# Processing Record 19 of Set 10 | kamaishi
# Processing Record 20 of Set 10 | vieques
# Processing Record 21 of Set 10 | kharan
# Processing Record 22 of Set 10 | kaz
# Processing Record 23 of Set 10 | ola
# Processing Record 24 of Set 10 | stornoway
# Processing Record 25 of Set 10 | cabedelo
# Processing Record 26 of Set 10 | alyangula
# Processing Record 27 of Set 10 | leninsk
# Processing Record 28 of Set 10 | okha
# Processing Record 29 of Set 10 | hami
# Processing Record 30 of Set 10 | matiari
# Processing Record 31 of Set 10 | swellendam
# Processing Record 32 of Set 10 | zyryanovsk
# Processing Record 33 of Set 10 | bowmore
# Processing Record 34 of Set 10 | inhambane
# Processing Record 35 of Set 10 | prudyanka
# Processing Record 36 of Set 10 | jinchang
# Processing Record 37 of Set 10 | mandurah
# Processing Record 38 of Set 10 | broome
# Processing Record 39 of Set 10 | kloulklubed
# Processing Record 40 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 41 of Set 10 | itaituba
# Processing Record 42 of Set 10 | mbaiki
# Processing Record 43 of Set 10 | muhammadabad
# Processing Record 44 of Set 10 | eureka
# Processing Record 45 of Set 10 | sambava
# Processing Record 46 of Set 10 | edwardsville
# Processing Record 47 of Set 10 | pangnirtung
# Processing Record 48 of Set 10 | changji
# Processing Record 49 of Set 10 | mazabuka
# Processing Record 50 of Set 10 | popondetta
# Processing Record 1 of Set 11 | nuevo progreso
# Processing Record 2 of Set 11 | narsaq
# Processing Record 3 of Set 11 | na klang
# Processing Record 4 of Set 11 | tucurui
# Processing Record 5 of Set 11 | nizwa
# Processing Record 6 of Set 11 | hirna
# Processing Record 7 of Set 11 | buon me thuot
# City not found. Skipping...
# Processing Record 8 of Set 11 | cabo san lucas
# Processing Record 9 of Set 11 | vedaranniyam
# City not found. Skipping...
# Processing Record 10 of Set 11 | manggar
# Processing Record 11 of Set 11 | san carlos de bariloche
# Processing Record 12 of Set 11 | minas de barroteran
# Processing Record 13 of Set 11 | morondava
# Processing Record 14 of Set 11 | edcor
# City not found. Skipping...
# Processing Record 15 of Set 11 | wajima
# Processing Record 16 of Set 11 | trojes
# Processing Record 17 of Set 11 | lasa
# Processing Record 18 of Set 11 | kholodnyy
# Processing Record 19 of Set 11 | sao bernardo
# Processing Record 20 of Set 11 | rawannawi
# City not found. Skipping...
# Processing Record 21 of Set 11 | lisakovsk
# Processing Record 22 of Set 11 | le pradet
# Processing Record 23 of Set 11 | cheuskiny
# City not found. Skipping...
# Processing Record 24 of Set 11 | zeya
# Processing Record 25 of Set 11 | muyinga
# Processing Record 26 of Set 11 | baculin
# Processing Record 27 of Set 11 | sibut
# Processing Record 28 of Set 11 | ramsgate
# Processing Record 29 of Set 11 | sonsonate
# Processing Record 30 of Set 11 | kungurtug
# Processing Record 31 of Set 11 | muros
# Processing Record 32 of Set 11 | wakkanai
# Processing Record 33 of Set 11 | villarrica
# Processing Record 34 of Set 11 | bontang
# Processing Record 35 of Set 11 | kensington
# Processing Record 36 of Set 11 | los llanos de aridane
# Processing Record 37 of Set 11 | port hedland
# Processing Record 38 of Set 11 | canora
# Processing Record 39 of Set 11 | jiayuguan
# Processing Record 40 of Set 11 | port hardy
# Processing Record 41 of Set 11 | kodiak
# Processing Record 42 of Set 11 | madhupur
# Processing Record 43 of Set 11 | bahia honda
# Processing Record 44 of Set 11 | general pico
# Processing Record 45 of Set 11 | mandalgovi
# Processing Record 46 of Set 11 | olafsvik
# Processing Record 47 of Set 11 | charneca de caparica
# Processing Record 48 of Set 11 | vardo
# Processing Record 49 of Set 11 | buchanan
# Processing Record 50 of Set 11 | petrivka
# Processing Record 1 of Set 12 | koslan
# Processing Record 2 of Set 12 | jasper
# Processing Record 3 of Set 12 | helong
# Processing Record 4 of Set 12 | verkh-chebula
# Processing Record 5 of Set 12 | arman
# Processing Record 6 of Set 12 | nyrob
# Processing Record 7 of Set 12 | taksimo
# Processing Record 8 of Set 12 | pabna
# Processing Record 9 of Set 12 | wanning
# Processing Record 10 of Set 12 | nyagan
# Processing Record 11 of Set 12 | mulege
# Processing Record 12 of Set 12 | hvolsvollur
# Processing Record 13 of Set 12 | rio cuarto
# Processing Record 14 of Set 12 | kununurra
# Processing Record 15 of Set 12 | verkh-usugli
# Processing Record 16 of Set 12 | khormuj
# City not found. Skipping...
# Processing Record 17 of Set 12 | provideniya
# Processing Record 18 of Set 12 | bubaque
# Processing Record 19 of Set 12 | guiratinga
# Processing Record 20 of Set 12 | labuhan
# Processing Record 21 of Set 12 | bom jesus
# Processing Record 22 of Set 12 | ekhabi
# Processing Record 23 of Set 12 | sao joao da barra
# Processing Record 24 of Set 12 | karaul
# City not found. Skipping...
# Processing Record 25 of Set 12 | aragarcas
# Processing Record 26 of Set 12 | kaeo
# Processing Record 27 of Set 12 | dunedin
# Processing Record 28 of Set 12 | dwarka
# Processing Record 29 of Set 12 | pacific grove
# Processing Record 30 of Set 12 | hihifo
# City not found. Skipping...
# Processing Record 31 of Set 12 | san rafael
# Processing Record 32 of Set 12 | palana
# Processing Record 33 of Set 12 | samusu
# City not found. Skipping...
# Processing Record 34 of Set 12 | edgewater
# Processing Record 35 of Set 12 | gumdag
# Processing Record 36 of Set 12 | binghamton
# Processing Record 37 of Set 12 | ranong
# Processing Record 38 of Set 12 | marienburg
# Processing Record 39 of Set 12 | pelym
# Processing Record 40 of Set 12 | salalah
# Processing Record 41 of Set 12 | porto torres
# Processing Record 42 of Set 12 | praia da vitoria
# Processing Record 43 of Set 12 | nantucket
# Processing Record 44 of Set 12 | acari
# Processing Record 45 of Set 12 | le moule
# Processing Record 46 of Set 12 | alotau
# City not found. Skipping...
# Processing Record 47 of Set 12 | arnprior
# Processing Record 48 of Set 12 | bowen
# Processing Record 49 of Set 12 | kulhudhuffushi
# Processing Record 50 of Set 12 | foggia
# Processing Record 1 of Set 13 | honiara
# Processing Record 2 of Set 13 | duncan
# Processing Record 3 of Set 13 | yeletskiy
# City not found. Skipping...
# Processing Record 4 of Set 13 | krasnoyarsk-66
# City not found. Skipping...
# Processing Record 5 of Set 13 | zelenoborskiy
# Processing Record 6 of Set 13 | dhidhdhoo
# Processing Record 7 of Set 13 | sibu
# Processing Record 8 of Set 13 | victor harbor
# Processing Record 9 of Set 13 | lamar
# Processing Record 10 of Set 13 | dzhebariki-khaya
# Processing Record 11 of Set 13 | marcona
# City not found. Skipping...
# Processing Record 12 of Set 13 | flinders
# Processing Record 13 of Set 13 | tabas
# Processing Record 14 of Set 13 | henties bay
# Processing Record 15 of Set 13 | eyl
# Processing Record 16 of Set 13 | antigonish
# Processing Record 17 of Set 13 | wattegama
# Processing Record 18 of Set 13 | flin flon
# Processing Record 19 of Set 13 | mayo
# Processing Record 20 of Set 13 | sobolevo
# Processing Record 21 of Set 13 | pozo colorado
# Processing Record 22 of Set 13 | kondinskoye
# Processing Record 23 of Set 13 | kuminskiy
# Processing Record 24 of Set 13 | madison
# Processing Record 25 of Set 13 | tungkang
# City not found. Skipping...
# Processing Record 26 of Set 13 | gloversville
# Processing Record 27 of Set 13 | kankan
# Processing Record 28 of Set 13 | swan hill
# Processing Record 29 of Set 13 | qingyuan
# Processing Record 30 of Set 13 | bathsheba
# Processing Record 31 of Set 13 | iskateley
# Processing Record 32 of Set 13 | mareeba
# Processing Record 33 of Set 13 | sioux lookout
# Processing Record 34 of Set 13 | flagstaff
# Processing Record 35 of Set 13 | banfora
# Processing Record 36 of Set 13 | belmonte
# Processing Record 37 of Set 13 | lesozavodsk
# Processing Record 38 of Set 13 | broken hill
# Processing Record 39 of Set 13 | raudeberg
# Processing Record 40 of Set 13 | tual
# Processing Record 41 of Set 13 | puerto madero
# Processing Record 42 of Set 13 | danjiangkou
# Processing Record 43 of Set 13 | viedma
# Processing Record 44 of Set 13 | giyani
# Processing Record 45 of Set 13 | kerema
# Processing Record 46 of Set 13 | tezu
# Processing Record 47 of Set 13 | toyooka
# Processing Record 48 of Set 13 | antofagasta
# Processing Record 49 of Set 13 | nichinan
# Processing Record 50 of Set 13 | yeppoon
# Processing Record 1 of Set 14 | la gaulette
# City not found. Skipping...
# Processing Record 2 of Set 14 | la macarena
# Processing Record 3 of Set 14 | fondi
# Processing Record 4 of Set 14 | dera bugti
# Processing Record 5 of Set 14 | baykit
# Processing Record 6 of Set 14 | rapid valley
# Processing Record 7 of Set 14 | tavares
# Processing Record 8 of Set 14 | sangolqui
# Processing Record 9 of Set 14 | bossembele
# City not found. Skipping...
# Processing Record 10 of Set 14 | jiaojiang
# Processing Record 11 of Set 14 | acapulco
# Processing Record 12 of Set 14 | ahipara
# Processing Record 13 of Set 14 | namatanai
# Processing Record 14 of Set 14 | le mars
# Processing Record 15 of Set 14 | kattivakkam
# Processing Record 16 of Set 14 | mudyuga
# City not found. Skipping...
# Processing Record 17 of Set 14 | lahij
# Processing Record 18 of Set 14 | bundaberg
# Processing Record 19 of Set 14 | vestbygda
# City not found. Skipping...
# Processing Record 20 of Set 14 | maltahohe
# Processing Record 21 of Set 14 | ystad
# Processing Record 22 of Set 14 | loding
# Processing Record 23 of Set 14 | manado
# Processing Record 24 of Set 14 | bambanglipuro
# Processing Record 25 of Set 14 | provost
# Processing Record 26 of Set 14 | evensk
# Processing Record 27 of Set 14 | kastamonu
# Processing Record 28 of Set 14 | pangody
# Processing Record 29 of Set 14 | yangjiang
# Processing Record 30 of Set 14 | myitkyina
# Processing Record 31 of Set 14 | westport
# Processing Record 32 of Set 14 | naica
# Processing Record 33 of Set 14 | porto nacional
# Processing Record 34 of Set 14 | temaraia
# City not found. Skipping...
# Processing Record 35 of Set 14 | taga
# Processing Record 36 of Set 14 | jalu
# Processing Record 37 of Set 14 | saint-jerome
# Processing Record 38 of Set 14 | baghmara
# Processing Record 39 of Set 14 | churapcha
# Processing Record 40 of Set 14 | nizhniy tsasuchey
# Processing Record 41 of Set 14 | kamennomostskiy
# Processing Record 42 of Set 14 | ballina
# Processing Record 43 of Set 14 | gunupur
# Processing Record 44 of Set 14 | khandyga
# Processing Record 45 of Set 14 | sebinkarahisar
# Processing Record 46 of Set 14 | napasar
# Processing Record 47 of Set 14 | abnub
# Processing Record 48 of Set 14 | inverness
# Processing Record 49 of Set 14 | edd
# Processing Record 50 of Set 14 | carambei
# Processing Record 1 of Set 15 | trujillo
# Processing Record 2 of Set 15 | shelburne
# Processing Record 3 of Set 15 | arrecife
# Processing Record 4 of Set 15 | kyzyl-suu
# Processing Record 5 of Set 15 | imbituba
# Processing Record 6 of Set 15 | falealupo
# City not found. Skipping...
# Processing Record 7 of Set 15 | crateus
# Processing Record 8 of Set 15 | arecibo
# Processing Record 9 of Set 15 | laguna
# Processing Record 10 of Set 15 | nizhneyansk
# City not found. Skipping...
# Processing Record 11 of Set 15 | mumford
# Processing Record 12 of Set 15 | amapa
# Processing Record 13 of Set 15 | pio xii
# Processing Record 14 of Set 15 | matata
# Processing Record 15 of Set 15 | chemal
# Processing Record 16 of Set 15 | pombas
# Processing Record 17 of Set 15 | korsakov
# Processing Record 18 of Set 15 | pundaguitan
# Processing Record 19 of Set 15 | wellington
# Processing Record 20 of Set 15 | nakamura
# Processing Record 21 of Set 15 | skibbereen
# Processing Record 22 of Set 15 | pryozerne
# Processing Record 23 of Set 15 | hervey bay
# Processing Record 24 of Set 15 | tahoua
# Processing Record 25 of Set 15 | general roca
# Processing Record 26 of Set 15 | mergui
# City not found. Skipping...
# Processing Record 27 of Set 15 | san ramon
# Processing Record 28 of Set 15 | port augusta
# Processing Record 29 of Set 15 | lazaro cardenas
# Processing Record 30 of Set 15 | majene
# Processing Record 31 of Set 15 | iralaya
# Processing Record 32 of Set 15 | luis correia
# Processing Record 33 of Set 15 | sept-iles
# Processing Record 34 of Set 15 | tidore
# City not found. Skipping...
# Processing Record 35 of Set 15 | bayshore gardens
# Processing Record 36 of Set 15 | soyo
# Processing Record 37 of Set 15 | pavino
# Processing Record 38 of Set 15 | fenelon falls
# Processing Record 39 of Set 15 | dauphin
# Processing Record 40 of Set 15 | almazar
# Processing Record 41 of Set 15 | ashland
# Processing Record 42 of Set 15 | aquiraz
# Processing Record 43 of Set 15 | sangar
# Processing Record 44 of Set 15 | svetlogorsk
# Processing Record 45 of Set 15 | san luis
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Preobrazheniye  42.9019  133.9064     48.96        52           0
# 1         Huarmey -10.0681  -78.1522     65.03        76          28
# 2         Renfrew  55.8720   -4.3925     58.51        80         100
# 3     Tuktoyaktuk  69.4541 -133.0374     44.60        93         100
# 4          Atuona  -9.8000 -139.0333     76.41        76          30
# 5    Ponta Do Sol  32.6667  -17.1000     74.03        90          44
# 6         Rikitea -23.1203 -134.9692     73.17        77           0
# 7           Bluff -46.6000  168.3333     46.80        85          99
# 8       Cape Town -33.9258   18.4232     62.38        71           0
# 9      Nikolskoye  59.7035   30.7861     49.91        96          62
#
#    Wind Speed Country Current Description
# 0        4.90      RU           clear sky
# 1       13.62      PE    scattered clouds
# 2        4.61      GB     overcast clouds
# 3        8.05      CA          light rain
# 4       19.98      PF          light rain
# 5        3.67      PT    scattered clouds
# 6       14.99      PF           clear sky
# 7        2.39      NZ     overcast clouds
# 8        5.75      ZA           clear sky
# 9        3.33      RU       broken clouds

# %%
new_column_order = ["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head()
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Preobrazheniye      RU  42.9019  133.9064     48.96        52           0
# 1         Huarmey      PE -10.0681  -78.1522     65.03        76          28
# 2         Renfrew      GB  55.8720   -4.3925     58.51        80         100
# 3     Tuktoyaktuk      CA  69.4541 -133.0374     44.60        93         100
# 4          Atuona      PF  -9.8000 -139.0333     76.41        76          30
#
#    Wind Speed Current Description
# 0        4.90           clear sky
# 1       13.62    scattered clouds
# 2        4.61     overcast clouds
# 3        8.05          light rain
# 4       19.98          light rain

# %%
# Create the output file (CSV).
output_data_file = "Weather_database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
